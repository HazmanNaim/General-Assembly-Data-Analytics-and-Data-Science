# %% [markdown]
# # Feature Importance

# %% [markdown]
# 1. Import modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import _________________
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
from sklearn.inspection import ______________

# %% [markdown]
# 2. Load dataset, split inputs and target

# %%
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.Series(iris.target)

# %% [markdown]
# 3. Split training and testing sets

# %%
X_train, X_test, y_train, y_test = __________________(X, y, test_size=0.2, random_state=42)

# %% [markdown]
# 4. Perform modeling

# %%
rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(X_train, y_train)

# Predictions
y_pred = rf_classifier.predict(X_test)

# Calculate accuracy
accuracy = __________________(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 1.00

# %% [markdown]
# 5. Permutation Importance

# %%
perm_importance = ___________________________(rf_classifier, X_test, y_test, n_repeats=30, random_state=42)

# Get feature names
feature_names = X_test.columns

# Calculate mean importance and sort features
mean_importance = _________________________________
sorted_idx = ___________________________

# Plot permutation importance
plt.barh(range(len(sorted_idx)), __________________________, align='center')
plt.yticks(range(len(sorted_idx)), _________________________________)
plt.xlabel('Permutation Importance')
plt.title('Permutation Importance (Random Forest)')
plt.show()

# %% [markdown]
# 6. Random Forest Feature Importance

# %%
# Get feature importances from RandomForest
rf_feature_importances = _______________________________

# Sort features by importance
sorted_idx_rf = ___________________________________

# Plot feature importances from RandomForest
plt.barh(range(len(sorted_idx_rf)), ___________________________________, align='center')
plt.yticks(range(len(sorted_idx_rf)), [feature_names[i] for i in sorted_idx_rf])
plt.xlabel('Feature Importance')
plt.title('Feature Importance (Random Forest)')
plt.show()
